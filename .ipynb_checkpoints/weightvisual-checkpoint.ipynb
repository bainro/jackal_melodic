# %%
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx
from utils import *
from placecell import PlaceNetwork

# %%
network = PlaceNetwork()
data = loadNetwork("test_8")
network.loadFromFile(data)
network.plotCells()
plt.show()

# %%
ids = [cell.ID for cell in network.cells]
pos = [(network.points[cell.ID][1], network.points[cell.ID][0]) for cell in network.cells]


ids_pts = [str(i) for i in pos]
pos_d = dict(zip(ids, pos))

# %%
edges = []
for cell in network.cells:
    for connected in cell.wgts.keys():
        edges.append((cell.ID, connected))

# %%
G = nx.Graph()

for cell in network.cells:
    G.add_node(f"{x}, {MAPSIZEY - 1 - y}",pos=(x*XSCALE,y*YSCALE), weight=weight)

plt.figure(figsize=(30, 30))
nodes = nx.draw_networkx_nodes(
    G, 
    edges, 
    node_size=5000)
edges = nx.draw_networkx_edges(
    G,
    edges,
    node_size=5000,
    arrowstyle="->",
    arrowsize=15,
    connectionstyle='arc3, rad=0.1')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19092/3967437982.py in <module>
#       3 G.add_edges_from(edges)
#       4 plt.figure(figsize=(30, 30))
# ----> 5 nodes = nx.draw_networkx_nodes(
#       6     G,
#       7     edges,
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\networkx\drawing\nx_pylab.py in draw_networkx_nodes(G, pos, nodelist, node_size, node_color, node_shape, alpha, cmap, vmin, vmax, ax, linewidths, edgecolors, label, margins)
#     452
#     453     try:
# --> 454         xy = np.asarray([pos[v] for v in nodelist])
#     455     except KeyError as err:
#     456         raise nx.NetworkXError(f"Node {err} has no position.") from err
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\networkx\drawing\nx_pylab.py in <listcomp>(.0)
#     452
#     453     try:
# ...

# %%
G = nx.Graph()

G.add_nodes_from(ids)
G.add_edges_from(edges)
plt.figure(figsize=(30, 30))
nx.draw(G, pos_d, with_labels=True, node_color="skyblue", node_size=5000, font_size=20)
plt.show()
